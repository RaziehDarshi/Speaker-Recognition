# %% [markdown]
# ***This code gets a wav audio file and splits it into 1 second slices***

# %%
# !pip install pydub # Pydub lets you manipulate audio with an simple and easy high level interface
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# import needed libraries
from pydub import AudioSegment
from pydub.utils import make_chunks
from google.colab import files
import os

# %%
os.mkdir('/content/new') # make directory
os.mkdir('/content/new/splited') # make new folder
os.chdir('/content') # change directory

# %%
files.upload() # upload the wav audio file
# Out:
#      <input type="file" id="files-306bc203-2f86-4bc5-be94-c2c20f75a641" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-306bc203-2f86-4bc5-be94-c2c20f75a641">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! pip install glob2
import glob2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
name = glob2.glob('*.wav')
name
# Out:
# ['Razieh.wav', 'Ar.wav']

# %%
#waves = glob.glob(folder+'/'+ '*.wav')
myaudio = AudioSegment.from_file(name[0] , "wav") # exposes a wrapper of a pydub.AudioSegment object
chunk_length_ms = 1000 # pydub calculates in millisec
chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of one sec

#Export all of the individual chunks as wav files

for i, chunk in enumerate(chunks):
    chunk_name = "chunk{0}.wav".format(i)
    print("exporting", chunk_name)
    chunk.export('/content/new/splited/' + chunk_name, format="wav") # download the exported file in chunks
# Out:
# exporting chunk0.wav
# exporting chunk1.wav
# exporting chunk2.wav
# exporting chunk3.wav
# exporting chunk4.wav
# exporting chunk5.wav
# exporting chunk6.wav
# exporting chunk7.wav
# exporting chunk8.wav
# exporting chunk9.wav
# exporting chunk10.wav
# exporting chunk11.wav
# exporting chunk12.wav
# exporting chunk13.wav

# %%
# !zip -r ./OneSecFiles.zip /content/new/splited # zip new chunked files
# Out:
# updating: content/new/splited/ (stored 0%)
# updating: content/new/splited/chunk2.wav (deflated 8%)
# updating: content/new/splited/chunk0.wav (deflated 40%)
# updating: content/new/splited/chunk9.wav (deflated 6%)
# updating: content/new/splited/chunk7.wav (deflated 9%)
# updating: content/new/splited/chunk4.wav (deflated 9%)
# updating: content/new/splited/chunk3.wav (deflated 9%)
# updating: content/new/splited/chunk10.wav (deflated 7%)
# updating: content/new/splited/chunk8.wav (deflated 14%)
# updating: content/new/splited/chunk6.wav (deflated 10%)
# updating: content/new/splited/chunk5.wav (deflated 9%)
# updating: content/new/splited/chunk1.wav (deflated 8%)
# updating: content/new/splited/chunk11.wav (deflated 8%)
#   adding: content/new/splited/chunk13.wav (deflated 25%)
#   adding: content/new/splited/chunk12.wav (deflated 15%)

# %%
files.download('OneSecFiles.zip') # download the 1 second files
